# %%
from IPython.display import clear_output

def display_board(board):
    line = "|"
    fill = ""
    clear_output()
    
    print ((line.rjust(10))+(line.rjust(10))+(fill.rjust(10))+"\n"
      +(board[7].center(9))+line+(board[8].center(9))+line+(board[9].center(10))+"\n"
      +(line.rjust(10))+(line.rjust(10))+(fill.rjust(10))+"\n"
       +(fill.rjust(30,"-"))+"\n"
      +(line.rjust(10))+(line.rjust(10))+(fill.rjust(10))+"\n"
      +(board[4].center(9))+line+(board[5].center(9))+line+(board[6].center(10))+"\n"
      +(line.rjust(10))+(line.rjust(10))+(fill.rjust(10))+"\n"
       +(fill.rjust(30,"-"))+"\n"
      +(line.rjust(10))+(line.rjust(10))+(fill.rjust(10))+"\n"
      +(board[1].center(9))+line+(board[2].center(9))+line+(board[3].center(10))+"\n"
      +(line.rjust(10))+(line.rjust(10))+(fill.rjust(10)))
    
def player_input():
    
    '''
    OUTPUT = (Player 1 marker, Player 2 marker)
    '''

    marker = ''
    
    while marker != 'X' and marker != 'O':
        marker = input('Player 1: Choose X or O: ').upper()
        
    if marker == 'X':
        
        return ('X','O')
    else:
        return ('O','X')
    
def place_marker(board, marker, position):
    board[position] = marker
    
def win_check(board, mark):
    
    # WIN TIC TAC TOE?
    return((board[1] == board[2] == board[3] == mark) or
    (board[4] == board[5] == board[6] == mark) or
    (board[7] == board[8] == board[9] == mark) or
    (board[1] == board[4] == board[7] == mark) or
    (board[2] == board[5] == board[8] == mark) or
    (board[3] == board[6] == board[9] == mark) or
    (board[1] == board[5] == board[9] == mark) or
    (board[7] == board[5] == board[3] == mark))

import random

def choose_first():
    
    flip = random.randint(0,1)
    
    if flip == 0:
        return 'Player 1'
    else:
        return 'Player 2'
    
def space_check(board, position):
    
    return board[position] == ' '

def full_board_check(board):
    
    for i in range(1,10):
        if space_check(board,i):
            return False
    #board is full if we return True
    return True

def player_choice(board):
    
    position = 0
    
    while position not in [1,2,3,4,5,6,7,8,9] or not space_check(board,position):
        position = int(input('Choose a position: (1-9) '))
        
    return position

def replay():
    
    input("Play again? Enter Yes or No")
    
    return choice == 'Yes'

# %%
# WHILE LOOP TO KEEP RUNNING THE GAME
print('Welcome to Tic Tac Toe!')

while True:
    # PLAY THE GAME
    #pass
    
    ## SET EVERYTHING UP (BOARD, WHO'S FIRST, CHOOSE MARKERS X,O)
    theBoard = [' '] * 10
    player1_marker, player2_marker = player_input()
    
    turn = choose_first()
    print(turn + ' will go girst')
    
    play_game = input('Ready to play? y or n?')
    
    if play_game.lower()[0] == 'y':
        game_on = True
    else:
        game_on = False
    
    ## GAME PLAY
    
    while game_on:
        
        #Player 1 Turn
        if turn == 'Player 1':
            #show the board, choose position, place marker
            display_board(theBoard)
            position = player_choice(theBoard)
            place_marker(theBoard, player1_marker, position)
            
            #check if they won
            if win_check(theBoard, player1_marker):
                display_board(theBoard)
                print('PLAYER 1 HAS WON!!')
                game_on = False
            #or check if there is a tie
            else:
                if full_board_check(theBoard):
                    display_board(theBoard)
                    print('TIE GAME!')
                    break
                #no tie and no win? then next player's turn
                else:
                    turn = 'Player 2'
        
        else:
            # Player2's turn.
            display_board(theBoard)
            position = player_choice(theBoard)
            place_marker(theBoard, player2_marker, position)
            
            #check if they won
            if win_check(theBoard, player2_marker):
                display(theBoard)
                print('PLAYER 2 HAS WON!!')
                game_on = False
            #or check if there is a tie
            else:
                if full_board_check(theBoard):
                    display_board(theBoard)
                    print('TIE GAME!')
                    break
            #no tie and no win? then next player's turn
                else:
                    turn = 'Player 1'
            #pass

    if not replay():
        break
    # BREAK OUT OF THE WHILE LOOP ON replay()
# Out:
#          |         |
#     O    |    X    |    X
#          |         |
# ------------------------------
#          |         |
#     O    |    X    |    O
#          |         |
# ------------------------------
#          |         |
#     X    |    O    |    X
#          |         |
# PLAYER 1 HAS WON!!
